# %% [markdown]
# Title : sentiment analysis on the IMDB movie reviews dataset using a Neural Network with an Embedding Layer.

# %%
import numpy as np
from tensorflow.keras.datasets import imdb
from tensorflow.keras.preprocessing.sequence import pad_sequences
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Embedding, Flatten, Dense

# Load the IMDB dataset
vocab_size = 10000  # Vocabulary size (top 10,000 most frequent words)
(x_train, y_train), (x_test, y_test) = imdb.load_data(num_words=vocab_size)

max_len = 200  # Maximum length of sequences

# Pad sequences to make them of equal length
x_train = pad_sequences(x_train, maxlen=max_len)
x_test = pad_sequences(x_test, maxlen=max_len)

# Define the model
model = Sequential([
    Embedding(vocab_size, 100, input_length=max_len),
    Flatten(),
    Dense(1, activation='sigmoid')
])

# Compile the model
model.compile(optimizer='adam', loss='binary_crossentropy', metrics=['accuracy'])

# Train the model
model.fit(x_train, y_train, epochs=10, batch_size=32, validation_data=(x_test, y_test))
# Out:
# Epoch 1/10
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 9s 11ms/step - accuracy: 0.7075 - loss: 0.5352 - val_accuracy: 0.8738 - val_loss: 0.2976
# Epoch 2/10
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 8s 11ms/step - accuracy: 0.9392 - loss: 0.1736 - val_accuracy: 0.8701 - val_loss: 0.3046
# Epoch 3/10
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 8s 11ms/step - accuracy: 0.9926 - loss: 0.0497 - val_accuracy: 0.8638 - val_loss: 0.3395
# Epoch 4/10
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 8s 11ms/step - accuracy: 0.9986 - loss: 0.0147 - val_accuracy: 0.8647 - val_loss: 0.3745
# Epoch 5/10
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 8s 11ms/step - accuracy: 0.9995 - loss: 0.0063 - val_accuracy: 0.8639 - val_loss: 0.4024
# Epoch 6/10
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 8s 11ms/step - accuracy: 1.0000 - loss: 0.0028 - val_accuracy: 0.8655 - val_loss: 0.4206
# Epoch 7/10
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 8s 11ms/step - accuracy: 1.0000 - loss: 0.0013 - val_accuracy: 0.8664 - val_loss: 0.4373
# Epoch 8/10
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 9s 11ms/step - accuracy: 1.0000 - loss: 7.6723e-04 - val_accuracy: 0.8671 - val_loss: 0.4577
# Epoch 9/10
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 8s 11ms/step - accuracy: 0.9996 - loss: 0.0021 - val_accuracy: 0.8529 - val_loss: 0.5253
# Epoch 10/10
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 8s 11ms/step - accuracy: 1.0000 - loss: 5.6789e-04 - val_accuracy: 0.8585 - val_loss: 0.5242

# %%
import matplotlib.pyplot as plt 
history = model.fit(x_train,y_train,epochs=5,batch_size=32,validation_data=(x_test,y_test))
plt.plot(history.history['accuracy'], label = "Training Accuracy")
plt.plot(history.history['val_accuracy'], label ="Validation Accuracy")
plt.xlabel("Epoch")
plt.ylabel("Accuracy")
plt.legend()
plt.show()
# Out:
# Epoch 1/5
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 8s 10ms/step - accuracy: 1.0000 - loss: 1.5988e-07 - val_accuracy: 0.8642 - val_loss: 0.8380
# Epoch 2/5
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 8s 10ms/step - accuracy: 1.0000 - loss: 1.2324e-07 - val_accuracy: 0.8640 - val_loss: 0.8534
# Epoch 3/5
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 8s 10ms/step - accuracy: 0.9998 - loss: 0.0017 - val_accuracy: 0.8393 - val_loss: 1.0104
# Epoch 4/5
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 8s 11ms/step - accuracy: 1.0000 - loss: 2.0136e-04 - val_accuracy: 0.8426 - val_loss: 1.0001
# Epoch 5/5
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 8s 11ms/step - accuracy: 1.0000 - loss: 3.8327e-06 - val_accuracy: 0.8434 - val_loss: 0.9957

# %%
plt.plot(history.history['loss'], label ="Training Loss")
plt.plot(history.history['val_loss'],label = "Validation Loss")
plt.xlabel("Epoch")
plt.ylabel("Loss")
plt.legend()
plt.show()
